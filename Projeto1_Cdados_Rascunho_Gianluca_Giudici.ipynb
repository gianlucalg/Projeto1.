# %% [markdown]
# # Projeto 1 - Rascunho
#
# ## Analise do crescimento economico de paises participantes da OCDE
#
# ### Organizaçao criada em 30 de setembro de 1961

# %%
#hipotese e mecanismo!!

#Importando bibliotecas que serao utilizadas:

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
from numpy import arange
from numpy import percentile
import numpy as np

# %% [markdown]
# # Pergunta:
#
# ### Dado o ano de entrada de um pais no bloco economico em um certo ano, qual o seu crescimento de GDP comparado aos paises do bloco e os que nao fazem parte?
#
# # Hipotese:
#
# ### Dado que o bloco OCDE (Organização de Cooperação e de Desenvolvimento Económico) tem por objetivo promover politicas que visem o desenvolvimento economico, acredita-se que a partir da entrada no mesmo, o crescimento economico dos paises aumentem em relaçao aos que nao fazem parte.

# %%
dados = pd.read_excel('GDPindustry.xlsx')

# %%
dados.head(30)
# Out:
#                    country   1960   1961   1962  1963  1964   1965  1966  \
# 0              Afghanistan    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 1                  Albania    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 2                  Algeria  29.40  29.50  31.70  40.8  42.7  42.20  46.5
# 3                  Andorra    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 4                   Angola    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 5      Antigua and Barbuda    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 6                Argentina    NaN    NaN    NaN   NaN   NaN  48.40  49.6
# 7                  Armenia    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 8                Australia    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 9                  Austria    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 10              Azerbaijan    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 11                 Bahamas    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# ...

# %%
#definindo o index para paises.

dados.set_index("country")
# Out:
#                          1960   1961   1962  1963  1964   1965  1966  1967  \
# country
# Afghanistan               NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Albania                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Algeria                 29.40  29.50  31.70  40.8  42.7  42.20  46.5  47.8
# Andorra                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Angola                    NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Antigua and Barbuda       NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Argentina                 NaN    NaN    NaN   NaN   NaN  48.40  49.6  47.4
# Armenia                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Australia                 NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Austria                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Azerbaijan                NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# ...

# %%
dadosdospaisesmembros = dados.set_index("country")

# %%
#Exemplo da aula:

#Fazer mecanismos "bolinha de gude e brincar na rua, entao maior frequencia de atropelamentos. Investigar isso."

# %%
dadosdospaisesmembros
# Out:
#                          1960   1961   1962  1963  1964   1965  1966  1967  \
# country
# Afghanistan               NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Albania                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Algeria                 29.40  29.50  31.70  40.8  42.7  42.20  46.5  47.8
# Andorra                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Angola                    NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Antigua and Barbuda       NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Argentina                 NaN    NaN    NaN   NaN   NaN  48.40  49.6  47.4
# Armenia                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Australia                 NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Austria                   NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# Azerbaijan                NaN    NaN    NaN   NaN   NaN    NaN   NaN   NaN
# ...

# %%
dados
# Out:
#                     country   1960   1961   1962  1963  1964   1965  1966  \
# 0               Afghanistan    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 1                   Albania    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 2                   Algeria  29.40  29.50  31.70  40.8  42.7  42.20  46.5
# 3                   Andorra    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 4                    Angola    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 5       Antigua and Barbuda    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 6                 Argentina    NaN    NaN    NaN   NaN   NaN  48.40  49.6
# 7                   Armenia    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 8                 Australia    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 9                   Austria    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 10               Azerbaijan    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# 11                  Bahamas    NaN    NaN    NaN   NaN   NaN    NaN   NaN
# ...

# %%
dadosdospaisesmembros2 = dadosdospaisesmembros.loc[["United States", "Mexico", "Japan", "Germany", "Turkey", "United Kingdom", "France", "Italy",
                            "South Korea", "Spain", "Poland", "Canada", "Australia", "Chile", "Netherlands", "Belgium",
                            "Czech Republic", "Greece", "Portugal", "Sweden", "Hungary", "Austria", "Switzerland",
                            "Denmark", "Finland", "Slovakia", "Norway", "Ireland", "New Zealand", "Estonia", "Luxembourg",
                            "Iceland"]]
# Out:
# /Users/macbookpro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """

# %%
#Paises membros da OCDE:
dadosdospaisesmembros2
# Out:
#                 1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# country
# United States    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Mexico           NaN   NaN   NaN   NaN   NaN  25.6  26.2  27.0  27.4  27.9
# Japan            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Germany          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Turkey          17.3  17.2  17.1  17.0  17.9  19.3  19.6  20.4  21.5  22.1
# United Kingdom   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# France          29.8  30.0  29.5  29.2  29.7  29.9  29.7  29.4  29.1  28.8
# Italy            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# South Korea     17.1  17.6  17.6  17.9  19.2  23.0  22.8  23.1  23.8  24.3
# Spain            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Poland           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
#Selecionando os 3 paises que entraram em 2010 no bloco que se tem dados, excluindo a Eslovenia.
since2010 = dadosdospaisesmembros.loc[["Chile", "Estonia", "Israel"]]

# %%
since2010
# Out:
#          1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...   \
# country                                                              ...
# Chile    33.8  33.8  35.8  37.7  38.4  38.0  37.4  37.9  39.4  40.7  ...
# Estonia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Israel    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#          2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# country
# Chile    34.2  34.4  35.7  34.7  32.5  31.2  30.8  29.7  28.9  30.0
# Estonia  26.3  23.4  24.5  25.6  25.1  25.2  24.9  24.0  23.1  23.5
# Israel   20.7  20.2  20.4  19.6  20.0  19.8  19.6  18.8  18.7   NaN
#
# [3 rows x 58 columns]

# %%
#Analisando o crescimento dos paises a partir de quando entraram no bloco recentemente(2010).
start=2003
end=2018

intervalo = np.arange(start, end, 1)
since2003 = since2010.loc[:,intervalo]

# %%
since2003
# Out:
#          2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# country
# Chile    33.4  36.0  36.9  41.1  39.9  34.2  34.4  35.7  34.7  32.5  31.2
# Estonia  26.1  25.5  26.4  26.9  27.1  26.3  23.4  24.5  25.6  25.1  25.2
# Israel   20.5  20.3  20.6  21.4  21.2  20.7  20.2  20.4  19.6  20.0  19.8
#
#          2014  2015  2016  2017
# country
# Chile    30.8  29.7  28.9  30.0
# Estonia  24.9  24.0  23.1  23.5
# Israel   19.6  18.8  18.7   NaN

# %%
#media de crescimento economico do chile antes de entrar no tratado:
x=7
y=33.4+36+36.9+41.1+39.9+34.2+34.4

def mediaantes (x, y):
    crescantes = y/x
    return crescantes

print (mediaantes(x, y))

mediaanteschile = 36.55714285714286

#media de crescimento economico depois de entrar no tratado:
z=7
w=34.7+32.5+31.2+30.8+29.7+28.9+30

def mediadepois (z, w):
    crescdepois = w/z
    return crescdepois

print (mediadepois(z, w))

mediadepoischile = 31.114285714285717
# Out:
# 36.55714285714286
# 31.114285714285717

# %%
#media de crescimento economico da Estonia antes de entrar no tratado:
x=7
y=26.1+25.5+26.4+26.9+27.1+26.3+23.4

def mediaantes2 (x,y):
    crescantes2 = y/x
    return crescantes2

print (mediaantes2(x, y))

mediaantesestonia = 25.95714285714286

#media de crescimento economico depois de entrar no tratado:
z=7
w=25.6+25.1+25.2+24.9+24+23.1+23.5

def mediadepois2 (z, w):
    crescdepois2 = w/z
    return crescdepois2

print (mediadepois(z, w))

mediadepoisestonia = 24.485714285714288
# Out:
# 25.95714285714286
# 24.485714285714288

# %%
#media de crescimento economico da Israel antes de entrar no tratado:
x=7
y=20.5+20.3+20.6+21.4+21.2+20.7+20.2

def mediaantes3 (x, y):
    crescantes3 = y/x
    return crescantes3
print (mediaantes3(x, y))

mediaantesisrael = 20.7

#media de crescimento economico depois de entrar no tratado:

z=6
w=19.6+20+19.8+19.6+18.8+18.7

def mediadepois3 (z, w):
    crescdepois3 = w/z
    return crescdepois3
print (mediadepois3(z, w))

mediadepoisisrael = 19.416666666666668
# Out:
# 20.7
# 19.416666666666668

# %%
#como podemos ver esta caindo o crescimento economico dos paises depois de entrarem no bloco em 2010.
since2003.plot(kind="bar", figsize=(20,10))

# %%
#os 3 paises que entraram no bloco em 2010 tiverem uma queda no crescimento economico, dos 7 anos antes e dos 7 apos! Porque isso aconteceu? 
#Sera que os outros paises do bloco tambem cairam na mesma epoca!

# %%
#paises que entraram em 1961:

since1961=dadosdospaisesmembros2.loc[["United States", "United Kingdom", "Turkey", "Switzerland", "Sweden", "Spain",
                                      "Portugal", "Norway", "Netherlands", "Luxembourg", "Ireland", "Iceland",
                                      "Greece", "Germany", "France", "Denmark", "Canada", "Belgium", "Austria"]]

# %%
since1961
# Out:
#                 1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# country
# United States    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United Kingdom   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Turkey          17.3  17.2  17.1  17.0  17.9  19.3  19.6  20.4  21.5  22.1
# Switzerland      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Sweden           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Spain            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Portugal         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Norway           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Netherlands      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  36.6
# Luxembourg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Ireland          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
since1961.plot(kind="line")

# %%
#Analisando o crescimento dos paises a partir de quando entraram no bloco em 1961, no mesmo intervalo de tempo(2003-2017):

start=2003
end=2018

intervalo2 = np.arange(start, end, 1)
since19612003 = since1961.loc[:,intervalo]

# %%
since19612003
# Out:
#                 2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# country
# United States   20.7  21.0  21.2  21.6  21.5  21.0  19.6  19.8  20.0  19.9
# United Kingdom  20.3  19.5  19.7  19.7  19.3  19.0  18.0  18.0  18.1  17.9
# Turkey          24.8  25.1  25.3  26.1  26.5  26.2  24.1  24.6  26.9  26.8
# Switzerland     26.1  25.9  26.0  26.2  26.2  26.5  25.5  25.6  26.0  25.7
# Sweden          25.8  26.2  26.1  26.6  26.7  25.9  23.6  25.4  24.9  23.7
# Spain           27.5  27.1  27.3  27.1  26.5  26.6  25.4  23.8  22.9  22.0
# Portugal        22.6  22.2  21.4  21.1  21.2  20.4  19.9  19.9  19.3  19.1
# Norway          33.4  35.0  38.0  39.7  37.2  40.3  34.3  34.7  37.0  36.8
# Netherlands     21.0  21.0  21.4  21.5  21.5  21.6  20.4  19.9  20.2  20.0
# Luxembourg      16.2  15.6  14.7  13.6  14.9  13.4  11.5  11.4  11.2  10.7
# Ireland         32.2  30.8  30.1  30.0  28.5  25.8  25.5  23.6  25.5  25.3
# ...

# %%
#grafico com muitas informaçoes, tenho que filtrar.

since1961transposto = since19612003.plot(kind="bar", legend=True)

# %%
#inverter as colunas e linhas para plotar por ano, facilitando a vizualizaçao:
